# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
# The URL from which to download the CSV
RESTAURANT_URL = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?fourfour=43nn-pn8j&cacheBust=1711046033&date=20240322&accessType=DOWNLOAD"

# Send a GET request to the URL
response = requests.get(RESTAURANT_URL)
# Check if the request was successful
if response.status_code == 200:
    # Open a file in binary write mode
    with open('restaurant_data.csv', 'wb') as file:
        # Write the content of the response to the file
        file.write(response.content)
    print("CSV file has been downloaded and saved as 'restaurant_data.csv'.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# CSV file has been downloaded and saved as 'restaurant_data.csv'.

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('restaurant_data.csv')

# %%
df_queens = df[df['BORO'] == 'Queens']

# %%
df_queens.shape
# Out:
# (53043, 27)

# %%
df_queens.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA', 'Location Point1'],
#       dtype='object')

# %%
df_queens
# Out:
#            CAMIS                                          DBA    BORO  \
# 0       50143838                       FAIRFIELD INN & SUITES  Queens
# 1       50148883                                    MOLLY TEA  Queens
# 2       50049739  CITI FIELD GOYA NACHOS & BURRITOS STAND 414  Queens
# 4       50106464              (FSE LOCATED IN JFK TERMINAL 8)  Queens
# 7       50101716                                Roosevelt BBQ  Queens
# ...          ...                                          ...     ...
# 223679  50066476                                  MERIT KABAB  Queens
# 223680  50082406                                  BURGER KING  Queens
# 223683  50138915                QUEENS BAGEL AND DELICATESSEN  Queens
# 223684  41523226              THE LITTLE CHINANTLA RESTAURANT  Queens
# 223685  50122495                   YUMMY A Chinese restaurant  Queens
#
#           BUILDING         STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0            14818     ARCHER AVE  11435.0  9177915754                 NaN
# 1            3711C      PRINCE ST  11354.0  9172387551                 NaN
# 2       126TH ST &  ROOSEVELT AVE      NaN  7185958192            American
# 4            14438       87TH AVE  11435.0  9176840703                 NaN
# 7            13688  ROOSEVELT AVE  11354.0  7188880997                 NaN
# ...            ...            ...      ...         ...                 ...
# 223679        3767        74TH ST  11372.0  7183965827         Bangladeshi
# 223680       12002    LIBERTY AVE  11419.0  9173005405          Hamburgers
# 223683       11520    QUEENS BLVD  11375.0  7188982121            American
# 223684        9606      43 AVENUE  11368.0  7182058999             Mexican
# 223685       15329  ROCKAWAY BLVD  11434.0  7185253828               Other
#
#        INSPECTION DATE                                             ACTION  \
# 0           01/01/1900                                                NaN
# 1           01/01/1900                                                NaN
# 2           06/05/2018  No violations were recorded at the time of thi...
# 4           01/01/1900                                                NaN
# 7           01/01/1900                                                NaN
# ...                ...                                                ...
# 223679      02/13/2023    Violations were cited in the following area(s).
# 223680      09/23/2021    Violations were cited in the following area(s).
# 223683      09/11/2023    Violations were cited in the following area(s).
# 223684      09/07/2023    Violations were cited in the following area(s).
# 223685      10/19/2022    Violations were cited in the following area(s).
#
#         ...                                    INSPECTION TYPE   Latitude  \
# 0       ...                                                NaN  40.700986
# 1       ...                                                NaN  40.760456
# 2       ...              Cycle Inspection / Initial Inspection   0.000000
# 4       ...                                                NaN  40.706793
# 7       ...                                                NaN  40.760184
# ...     ...                                                ...        ...
# 223679  ...                   Cycle Inspection / Re-inspection  40.747173
# 223680  ...              Cycle Inspection / Initial Inspection  40.686582
# 223683  ...      Pre-permit (Operational) / Initial Inspection  40.716294
# 223684  ...  Administrative Miscellaneous / Initial Inspection  40.745682
# 223685  ...      Pre-permit (Operational) / Initial Inspection  40.669761
#
#         Longitude  Community Board Council District Census Tract        BIN  \
# 0      -73.805825            412.0             27.0      20800.0  4619928.0
# 1      -73.832760            407.0             20.0      87100.0  4112279.0
# 2        0.000000              NaN              NaN          NaN        NaN
# 4      -73.811720            408.0             24.0      23200.0  4207368.0
# 7      -73.827599            407.0             20.0      85300.0  4583979.0
# ...           ...              ...              ...          ...        ...
# 223679 -73.891484            403.0             25.0      28900.0  4029814.0
# 223680 -73.823233            410.0             28.0      16600.0  4204288.0
# 223683 -73.833792            406.0             29.0      76902.0  4079940.0
# 223684 -73.867761            404.0             21.0      37500.0  4040398.0
# 223685 -73.782842            412.0             28.0      29400.0  4594692.0
#
#                  BBL   NTA  Location Point1
# 0       4.099980e+09  QN61              NaN
# 1       4.049740e+09  QN22              NaN
# 2       4.000000e+00   NaN              NaN
# 4       4.097030e+09  QN35              NaN
# 7       4.050190e+09  QN22              NaN
# ...              ...   ...              ...
# 223679  4.012850e+09  QN28              NaN
# 223680  4.095740e+09  QN55              NaN
# 223683  4.033420e+09  QN17              NaN
# 223684  4.016130e+09  QN26              NaN
# 223685  4.122920e+09  QN02              NaN
#
# [53043 rows x 27 columns]
