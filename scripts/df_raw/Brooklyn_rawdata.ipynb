# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
# The URL from which to download the CSV
RESTAURANT_URL = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?fourfour=43nn-pn8j&cacheBust=1711046033&date=20240322&accessType=DOWNLOAD"

# Send a GET request to the URL
response = requests.get(RESTAURANT_URL)
# Check if the request was successful
if response.status_code == 200:
    # Open a file in binary write mode
    with open('restaurant_data.csv', 'wb') as file:
        # Write the content of the response to the file
        file.write(response.content)
    print("CSV file has been downloaded and saved as 'restaurant_data.csv'.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# CSV file has been downloaded and saved as 'restaurant_data.csv'.

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('restaurant_data.csv')

# %%
df_brooklyn = df[df['BORO'] == 'Brooklyn']

df_brooklyn
# Out:
#            CAMIS                            DBA      BORO BUILDING  \
# 2       50140155                      KEYBAR BK  Brooklyn      143
# 4       50145465                        MR MELO  Brooklyn       61
# 6       50140135                          BAR56  Brooklyn       55
# 9       50148747                            NaN  Brooklyn      385
# 11      50143247  COSZCAL DE ALLENDE RESTAURANT  Brooklyn     7506
# ...          ...                            ...       ...      ...
# 226385  50041401                    FUSION EAST  Brooklyn     1165
# 226388  50131646                    GINJAN CAFE  Brooklyn      333
# 226392  50145559        TEX*S CHICKEN & BURGERS  Brooklyn     2028
# 226395  50065314                     SWEETGREEN  Brooklyn       50
# 226399  50059006                 GLAZE TERIYAKI  Brooklyn      145
#
#                      STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 2           TROUTMAN STREET  11206.0  6465545982                 NaN
# 4            WITHERS STREET  11211.0  9148261144                 NaN
# 6              WATER STREET  11201.0  9144711128                 NaN
# 9       FLATBUSH AVENUE EXT  11201.0  2138190492                 NaN
# 11                 3 AVENUE  11209.0  7187372166                 NaN
# ...                     ...      ...         ...                 ...
# 226385         ELTON STREET  11239.0  7189755065           Caribbean
# 226388      NOSTRAND AVENUE  11216.0  9292489696             African
# 226392          BATH AVENUE  11214.0  7185130420             Chicken
# 226395    WASHINGTON STREET  11201.0  3479874185              Salads
# 226399    NORTH    4 STREET  11211.0  3479873950            Japanese
#
#        INSPECTION DATE                                           ACTION  ...  \
# 2           01/01/1900                                              NaN  ...
# 4           01/01/1900                                              NaN  ...
# 6           01/01/1900                                              NaN  ...
# 9           01/01/1900                                              NaN  ...
# 11          01/01/1900                                              NaN  ...
# ...                ...                                              ...  ...
# 226385      02/23/2022  Violations were cited in the following area(s).  ...
# 226388      08/24/2023  Violations were cited in the following area(s).  ...
# 226392      04/22/2024  Violations were cited in the following area(s).  ...
# 226395      04/26/2022  Violations were cited in the following area(s).  ...
# 226399      10/11/2022  Violations were cited in the following area(s).  ...
#
#                                       INSPECTION TYPE   Latitude  Longitude  \
# 2                                                 NaN  40.700025 -73.929303
# 4                                                 NaN  40.716862 -73.950179
# 6                                                 NaN  40.703294 -73.992047
# 9                                                 NaN  40.690288 -73.981375
# 11                                                NaN  40.631323 -74.027856
# ...                                               ...        ...        ...
# 226385          Cycle Inspection / Initial Inspection  40.656053 -73.873720
# 226388  Pre-permit (Operational) / Initial Inspection  40.686818 -73.950850
# 226392  Pre-permit (Operational) / Initial Inspection  40.600845 -74.000702
# 226395           Calorie Posting / Initial Inspection  40.702827 -73.989617
# 226399          Cycle Inspection / Initial Inspection  40.715981 -73.959198
#
#         Community Board Council District Census Tract        BIN  \
# 2                 304.0             34.0      42500.0  3072256.0
# 4                 301.0             33.0      51500.0  3338065.0
# 6                 302.0             33.0       2100.0  3000019.0
# 9                 302.0             35.0       3100.0  3338887.0
# 11                310.0             43.0       6600.0  3148679.0
# ...                 ...              ...          ...        ...
# 226385            305.0             42.0     107000.0  3398621.0
# 226388            303.0             36.0      25100.0  3050881.0
# 226392            311.0             47.0      28600.0  3168847.0
# 226395            302.0             33.0       2100.0  3329425.0
# 226399            301.0             34.0      55300.0  3062334.0
#
#                  BBL   NTA  Location Point1
# 2       3.031720e+09  BK78              NaN
# 4       3.027360e+09  BK73              NaN
# 6       3.000260e+09  BK38              NaN
# 9       3.020858e+09  BK68              NaN
# 11      3.059390e+09  BK31              NaN
# ...              ...   ...              ...
# 226385  3.044528e+09  BK82              NaN
# 226388  3.018080e+09  BK75              NaN
# 226392  3.064430e+09  BK27              NaN
# 226395  3.000370e+09  BK38              NaN
# 226399  3.023440e+09  BK73              NaN
#
# [60878 rows x 27 columns]

# %%
df_brooklyn = pd.concat([df_brooklyn], ignore_index=True)

# %%
df_brooklyn.shape
# Out:
# (60878, 27)
