# %%
import pandas as pd
import numpy as np
import requests
import json

# The URL from which to download the CSV
RESTAURANT_URL = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?fourfour=43nn-pn8j&cacheBust=1711046033&date=20240322&accessType=DOWNLOAD"

# Send a GET request to the URL
response = requests.get(RESTAURANT_URL)
# Check if the request was successful
if response.status_code == 200:
    # Open a file in binary write mode
    with open('restaurant_data.csv', 'wb') as file:
        # Write the content of the response to the file
        file.write(response.content)
    print("CSV file has been downloaded and saved as 'restaurant_data.csv'.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# CSV file has been downloaded and saved as 'restaurant_data.csv'.

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('restaurant_data.csv')

# %%
df_bronx = df[df['BORO'] == 'Bronx']

df_statenisland = df[df['BORO'] == 'Staten Island']

df_statenisland
# Out:
#            CAMIS                                  DBA           BORO BUILDING  \
# 22      50045516                         FUNKY MONKEY  Staten Island     1205
# 33      50097242                                 KPOT  Staten Island     1756
# 171     50131405            BLAZE JAMAICAN RESTAURANT  Staten Island        3
# 278     50123157              CHARLIE'S SANDWICH SHOP  Staten Island      130
# 290     50094858                          METRO PIZZA  Staten Island     1218
# ...          ...                                  ...            ...      ...
# 223516  50088487  CHEF'S HONG II LI FAMILY RESTAURANT  Staten Island     7226
# 223535  41572685  BROOKLYNS FINEST PIZZA & RESTAURANT  Staten Island     1250
# 223558  41582708                     CANTINA MEXICANA  Staten Island      140
# 223592  40528073                          GRAND PLAZA  Staten Island       23
# 223609  41524226                         MIKEY BAGELS  Staten Island     7420
#
#                  STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 22        FOREST AVENUE  10310.0  7187205700               Irish
# 33        FOREST AVENUE  10303.0  9178300159              Korean
# 171       CORSON AVENUE  10301.0  9149790445           Soul Food
# 278      LINCOLN AVENUE  10306.0  7182854000             Italian
# 290       FOREST AVENUE  10310.0  7188122967               Pizza
# ...                 ...      ...         ...                 ...
# 223516       AMBOY ROAD  10307.0  7182270100             Chinese
# 223535  HYLAN BOULEVARD  10305.0  7188157070               Pizza
# 223558    NEW DORP LANE  10306.0  7183515474             Mexican
# 223592    NELSON AVENUE  10308.0  7189674034            American
# 223609       AMBOY ROAD  10307.0  7189849700            American
#
#        INSPECTION DATE                                           ACTION  ...  \
# 22          01/17/2024  Violations were cited in the following area(s).  ...
# 33          03/18/2024  Violations were cited in the following area(s).  ...
# 171         02/13/2023  Violations were cited in the following area(s).  ...
# 278         11/21/2023  Violations were cited in the following area(s).  ...
# 290         03/13/2023  Violations were cited in the following area(s).  ...
# ...                ...                                              ...  ...
# 223516      04/06/2022  Violations were cited in the following area(s).  ...
# 223535      03/01/2023  Violations were cited in the following area(s).  ...
# 223558      11/28/2022  Violations were cited in the following area(s).  ...
# 223592      03/23/2023  Violations were cited in the following area(s).  ...
# 223609      01/12/2022  Violations were cited in the following area(s).  ...
#
#                                       INSPECTION TYPE   Latitude  Longitude  \
# 22                   Cycle Inspection / Re-inspection  40.626399 -74.130244
# 33                   Cycle Inspection / Re-inspection  40.624968 -74.147457
# 171     Pre-permit (Operational) / Initial Inspection  40.638254 -74.079031
# 278             Cycle Inspection / Initial Inspection  40.579086 -74.108166
# 290             Cycle Inspection / Initial Inspection  40.626355 -74.130445
# ...                                               ...        ...        ...
# 223516          Cycle Inspection / Initial Inspection  40.512304 -74.239114
# 223535               Cycle Inspection / Re-inspection  40.597674 -74.084200
# 223558          Cycle Inspection / Initial Inspection  40.573734 -74.115926
# 223592          Cycle Inspection / Initial Inspection  40.549372 -74.150682
# 223609          Cycle Inspection / Initial Inspection  40.509922 -74.243921
#
#         Community Board Council District Census Tract        BIN  \
# 22                501.0             49.0      14100.0  5006484.0
# 33                501.0             49.0      30301.0  5150289.0
# 171               501.0             49.0       1100.0  5000293.0
# 278               502.0             50.0      12200.0  5107537.0
# 290               501.0             50.0      15100.0  5104902.0
# ...                 ...              ...          ...        ...
# 223516            503.0             51.0      24401.0  5107850.0
# 223535            502.0             50.0       6400.0  5047240.0
# 223558            502.0             50.0      13400.0  5057396.0
# 223592            503.0             51.0      13203.0  5065708.0
# 223609            503.0             51.0      24401.0  5088116.0
#
#                  BBL   NTA  Location Point1
# 22      5.002380e+09  SI22              NaN
# 33      5.014790e+09  SI12              NaN
# 171     5.000180e+09  SI22              NaN
# 278     5.036030e+09  SI45              NaN
# 290     5.003540e+09  SI07              NaN
# ...              ...   ...              ...
# 223516  5.078540e+09  SI11              NaN
# 223535  5.032200e+09  SI14              NaN
# 223558  5.042090e+09  SI45              NaN
# 223592  5.051430e+09  SI54              NaN
# 223609  5.078990e+09  SI11              NaN
#
# [8046 rows x 27 columns]
