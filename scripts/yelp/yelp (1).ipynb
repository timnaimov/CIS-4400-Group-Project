# %%
from google.cloud import storage
import pandas as pd
import pandas as pd
import numpy as np
import requests
import json
from io import StringIO

# Specify the name of your bucket
bucket_name = 'restaurant-dataset'

# Authenticate using a service account key
# Replace 'path/to/your/service-account-key.json' with the path to your service account key file
storage_client = storage.Client.from_service_account_json('/content/nyc-restaurants-419717-6cf4f9e6c135.json')

# Access the specified bucket
bucket = storage_client.bucket(bucket_name)
# Out:
#           CAMIS                                DBA           BORO BUILDING  \
# 0      50110282                    KARIBBEAN KRAVE          Bronx       65
# 1      41450634               YUNG HSIN RESTAURANT          Bronx   147577
# 2      41459414                      NEW YUNG HONG          Bronx      271
# 3      50150619  GOTHAM STADIUM TENNIS CENTER CAFE          Bronx      725
# 4      41232292                         PIZZA CHEF          Bronx      564
# ...         ...                                ...            ...      ...
# 28355  50119196                   SALLY'S SOUTHERN  Staten Island      427
# 28356  41463477           DUNKIN',' BASKIN ROBBINS  Staten Island      770
# 28357  41303560                     BLU ON THE BAY  Staten Island      492
# 28358  41571795                   KUM FUNG KITCHEN  Staten Island      838
# 28359  50109380                 TRIUNFO RESTAURANT  Staten Island      330
#
#                       STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0             WESTCHESTER SQ  10461.0  7186736759           Caribbean
# 1               BEACH AVENUE      NaN  7184095984             Chinese
# 2      WEST KINGSBRIDGE ROAD  10463.0  7185490030             Chinese
# 3            EXTERIOR STREET  10451.0  9149800750                 NaN
# 4           WEST  235 STREET  10463.0  7187964500               Pizza
# ...                      ...      ...         ...                 ...
# 28355          FOREST AVENUE  10301.0  7187272559            Barbecue
# 28356          FOREST AVENUE  10310.0  7182739641              Donuts
# 28357             BAY STREET  10304.0  7184201527             Spanish
# 28358             BAY STREET  10304.0  7187278888             Chinese
# 28359        HEBERTON AVENUE  10302.0  9173979242             Mexican
#
#       INSPECTION DATE                                             ACTION  ...  \
# 0          08/12/2022  No violations were recorded at the time of thi...  ...
# 1          05/17/2023    Violations were cited in the following area(s).  ...
# 2          06/24/2019  No violations were recorded at the time of thi...  ...
# 3          01/01/1900                                                NaN  ...
# 4          04/18/2022    Violations were cited in the following area(s).  ...
# ...               ...                                                ...  ...
# 28355      08/07/2023    Violations were cited in the following area(s).  ...
# 28356      02/07/2024    Violations were cited in the following area(s).  ...
# 28357      06/16/2017    Violations were cited in the following area(s).  ...
# 28358      03/14/2022    Violations were cited in the following area(s).  ...
# 28359      01/02/2024    Violations were cited in the following area(s).  ...
#
#                                          INSPECTION TYPE   Latitude  \
# 0      Administrative Miscellaneous / Initial Inspection  40.841234
# 1                  Cycle Inspection / Initial Inspection   0.000000
# 2                  Cycle Inspection / Initial Inspection  40.872850
# 3                                                    NaN  40.823458
# 4                  Cycle Inspection / Initial Inspection  40.885708
# ...                                                  ...        ...
# 28355           Pre-permit (Operational) / Re-inspection  40.630824
# 28356                   Cycle Inspection / Re-inspection  40.629075
# 28357                   Cycle Inspection / Re-inspection  40.630008
# 28358              Cycle Inspection / Initial Inspection  40.621941
# 28359              Cycle Inspection / Initial Inspection  40.632955
#
#        Longitude  Community Board Council District Census Tract        BIN  \
# 0     -73.842973            210.0             18.0      20000.0  2097357.0
# 1       0.000000              NaN              NaN          NaN        NaN
# 2     -73.905127            208.0             14.0      27300.0  2015865.0
# 3     -73.931021            204.0              8.0       6300.0  2097176.0
# 4     -73.910276            208.0             11.0      29700.0  2084102.0
# ...          ...              ...              ...          ...        ...
# 28355 -74.103542            501.0             49.0       6700.0  5003237.0
# 28356 -74.114938            501.0             49.0      12100.0  5008059.0
# 28357 -74.076740            501.0             49.0       2100.0  5106835.0
# 28358 -74.072142            501.0             49.0       4000.0  5042341.0
# 28359 -74.133942            501.0             49.0      21300.0  5093472.0
#
#                 BBL   NTA  Location Point1
# 0      2.040720e+09  BX37              NaN
# 1      2.000000e+00   NaN              NaN
# 2      2.032590e+09  BX28              NaN
# 3      2.025390e+09  BX63              NaN
# 4      2.057870e+09  BX29              NaN
# ...             ...   ...              ...
# 28355  5.001320e+09  SI35              NaN
# 28356  5.003000e+09  SI35              NaN
# 28357  5.005100e+09  SI37              NaN
# 28358  5.028360e+09  SI08              NaN
# 28359  5.010370e+09  SI28              NaN
#
# [28360 rows x 27 columns]

# %%
# Specify the folder name within the bucket
folder_name = 'df_raw'

#specify name of the CSV file in the bucket
blob = bucket.blob (f'{folder_name}/StatenIslandBronxInspect.csv')

# Download the CSV file
blob.download_to_filename('StatenIslandBronxInspect.csv')

# Read the CSV file into a DataFrame
statenislandbronx_df = pd.read_csv('StatenIslandBronxInspect.csv')

# Display the DataFrame
statenislandbronx_df

# %%
import math

StatenIslandBronx_df_sorted = StatenIslandBronx_df.sort_values(by=['Latitude', 'Longitude'], ascending=False)
StatenIslandBronx_df_sorted.head()


def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))

    # Radius of Earth in kilometers. Use 3956 for miles
    r = 6371

    # Calculate the result
    return c * r

StatenIslandBronx_df_sorted['prev_latitude'] = StatenIslandBronx_df_sorted['Latitude'].shift(1)
StatenIslandBronx_df_sorted['prev_longitude'] = StatenIslandBronx_df_sorted['Longitude'].shift(1)

# Step 3: Apply the Haversine function to calculate distances between consecutive rows
StatenIslandBronx_df_sorted['distance_to_prev'] = StatenIslandBronx_df_sorted.apply(lambda row: haversine(row['prev_latitude'], row['prev_longitude'], row['Latitude'], row['Longitude']), axis=1)
StatenIslandBronx_df_sorted

# Example usage
lat1, lon1 = 40.648313, -73.788281
lat2, lon2 = 40.685945, -73.793657
distance = haversine(lat1, lon1, lat2, lon2)
print(f"Distance: {distance} kilometers")
# Out:
# Distance: 4.2089819246733775 kilometers

# %%
# Initialize an empty DataFrame to accumulate Yelp data
df_yelp = pd.DataFrame()

#specify name of the CSV file in the bucket
blob = bucket.blob (f'{folder_name}/yelp_data.csv')

# Download the CSV file
blob.download_to_filename('yelp_data.csv')

# Read the CSV file into a DataFrame
processed_restaurants_df = pd.read_csv('yelp_data.csv')

# Display the DataFrame
print(processed_restaurants_df.shape)
# Out:
# (8972, 17)

# %%
# To continue extacting from where left off the last day
# ADJUST THE CSV NAME !!!

# Initialize an empty DataFrame to accumulate Yelp data
df_yelp = pd.DataFrame()

# Specify the name of the file to store processed restaurants' information
processed_restaurants_file = 'yelp_data.csv'

# Check if the file exists in Google Cloud Storage
processed_blob = bucket.blob(processed_restaurants_file)
if processed_blob.exists():
    # Download the file
    processed_blob.download_to_filename(processed_restaurants_file)
    # Read the file into a DataFrame
    processed_restaurants_df = pd.read_csv(processed_restaurants_file)
else:
    # If the file doesn't exist, create an empty DataFrame
    #processed_restaurants_df = pd.DataFrame(columns=['Latitude', 'Longitude'])
    print("does not exist")

# Loop through the DataFrame and print latitude and longitude. Upload Staten Island and Bronx restaurants to GCS
for index, row in StatenIslandBronx_df.iterrows():
    try:
        # Check if the restaurant has already been processed
        if ((processed_restaurants_df['Latitude'] == row['Latitude']) & (processed_restaurants_df['Longitude'] == row['Longitude'])).any():
            print(f"Restaurant at Latitude: {row['Latitude']} and Longitude: {row['Longitude']} already processed.")
            continue  # Skip processing this restaurant

        print(row['DBA'])
        # Make the request to the Yelp API
        url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={row['Latitude']}&longitude={row['Longitude']}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
        response = requests.get(url, headers=headers)

        # Check the status code
        if response.status_code == 200:
            # Parse the response
            yelp_data = response.json()

            # Check if 'businesses' key has rows
            if 'businesses' in yelp_data and yelp_data['businesses']:
                print("Business data found:")
                # Append Yelp data to the DataFrame
                df_yelp = df_yelp.append(pd.DataFrame(yelp_data['businesses']), ignore_index=True)
            else:
                print("No business data found in the response.")
        else:
            print(f"Request failed with status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        # Handle any exceptions that arise from the request
        print(f"An error occurred: {e}")

# Update processed_restaurants_df with the processed restaurants' information
processed_restaurants_df = processed_restaurants_df.append(StatenIslandBronx_df[['Latitude', 'Longitude']], ignore_index=True)

# Drop duplicates in case the same restaurant is processed multiple times
processed_restaurants_df.drop_duplicates(inplace=True)

# Upload processed_restaurants_df to Google Cloud Storage
processed_blob.upload_from_string(processed_restaurants_df.to_csv(index=False), content_type='text/csv')

# Define blob name and upload CSV to GCS
blob_name = "yelp/raw/all_restaurants.csv"  # Adjust blob name as needed
blob = bucket.blob(blob_name)
output = df_yelp.to_csv(index=False)
blob.upload_from_string(output, content_type='text/csv')

print("All restaurant data from Yelp has been uploaded to Google Cloud Storage.")

# %%
# #THIS ONE PRODUCES INDIVIDUAL CSV
# already used, combined csv files to one "yelp data" in other code

# # Define your Yelp API token
# TOKEN = "um5-Wc71JOtL5RyZ4mLQFRCRIld7DkPZGz3FXdUSHJD0rD4fleKZCxVtexS2gSiZBTabKU8g1h8SCAyTO5iaMAS6FkA8lcv5kve16VAHauLvVmrc0jll8XmYYsQuZnYx"
# headers = {
#     "accept": "application/json",
#     "Authorization": f"Bearer {TOKEN}"
# }

# rows_to_remove = []

# # Loop through the DataFrame and print latitude and longitude. Upload Staten Island and Bronx restaurants to GCS
# for index, row in StatenIslandBronx_df.iterrows():
#     try:
#         print(row['DBA'])
#         # Make the request to the Yelp API. The Radius is 100 meters because I believe based on the coordinates given by NYC, I will find at least the information from
#         url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={row['Latitude']}&longitude={row['Longitude']}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
#         response = requests.get(url, headers=headers)

#         # Check the status code
#         if response.status_code == 200:
#         # Parse the response
#             yelp_data = response.json()

#             # Check if 'businesses' key has rows
#             if 'businesses' in yelp_data and yelp_data['businesses']:
#                 print("Business data found:")
#                 df_yelp = pd.DataFrame(yelp_data['businesses'])
#                 print(df_yelp)

#                 # Define blob name and upload CSV to GCS
#                 blob_name = f"yelp/raw/{row['DBA']}.csv"  # Adjust blob name as needed
#                 blob = bucket.blob(blob_name)
#                 output = df_yelp.to_csv(index=False)
#                 blob.upload_from_string(output, content_type='text/csv')

#                 print(f"Restaurant: {row['DBA']}, Latitude: {row['Latitude']}, Longitude: {row['Longitude']} has been uploaded to Google Cloud Storage.")
#                 rows_to_remove.append(index)
#             else:
#                 print("No business data found in the response.")
#         else:
#             print(f"Request failed with status code: {response.status_code}")
#     except requests.exceptions.RequestException as e:
#         # Handle any exceptions that arise from the request
#         print(f"An error occurred: {e}")

# # Dropping rows that didn't return anything or where there was an error
# StatenIslandBronx_df.drop(rows_to_remove, inplace=True)
# StatenIslandBronx_df.reset_index(drop=True, inplace=True)

# # Upload the cleaned DataFrame to Google Cloud Storage
# blob_client = bucket.blob(f"/raw/inprocess/restaurants.csv")
# final_output = StatenIslandBronx_df.to_csv(index=False)
# blob_client.upload_from_string(final_output, content_type='text/csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# 1  {'address1': '987 Prospect Ave', 'address2': '...  +17188424075
# 2  {'address1': '921 Prospect Ave', 'address2': '...  +17183281500
# 3  {'address1': '963 Prospect Ave', 'address2': '...  +17188600267
# 4  {'address1': '910 Prospect Ave', 'address2': '...  +13472709231
# 5  {'address1': '948 Prospect Ave', 'address2': '...  +17186170290
# 6  {'address1': '963 Prospect Ave', 'address2': N...  +13475910674
# 7  {'address1': '923 Prospect Ave', 'address2': N...  +17183288073
#
#     display_phone    distance  \
# 0  (718) 942-5862   48.812035
# 1  (718) 842-4075   77.021037
# 2  (718) 328-1500  103.694741
# 3  (718) 860-0267   34.869204
# 4  (347) 270-9231   89.955108
# 5  (718) 617-0290   42.295767
# 6  (347) 591-0674   34.869204
# 7  (718) 328-8073   89.966872
#
#                                           attributes price
# 0  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 1  {'business_temp_closed': None, 'menu_url': 'ht...     $
# 2  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 3  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 4  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 5  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 6  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 7  {'business_temp_closed': None, 'menu_url': Non...   NaN
# Restaurant: BRIANNAS PIZZERIA AND SPANISH FOOD, Latitude: 40.82262873318, Longitude: -73.900404032222 has been uploaded to Google Cloud Storage.
# DUNKIN
# No business data found in the response.
# PAPA JOHN'S
# Business data found:
#                         id                                alias  \
# 0   pMUsX9vXcHcS9KTRbFewbw              picante-picante-bronx-4
# 1   8eEXaOwi-ld07IW8sQSLPg              louies-dale-diner-bronx
# 2   rOM3cMvWeXFBJvyk2Oui0g       broadway-pizza-and-pasta-bronx
# 3   Yj3pRPnIG05AjRfGP0Afjg       mei-chung-mei-restaurant-bronx
# 4   l-9AwcMeRIU9fT_e3lLsSA            papa-johns-pizza-bronx-22
# 5   RcDLM3c1H1USH1UtdaeUmA  bailey-seafood-and-kuchifrito-bronx
# 6   Wz2m9GvlDs84HYYvkuvzVw                 lauras-pizza-bronx-2
# 7   4MMIHYz8PmQmrB1JcwXarA      new-adventure-mini-market-bronx
# 8   xjBetPLLBDW_As-BLgnzNQ             dough-boys-pizza-bronx-2
# 9   5HAoEWeAO4pcQED83yAghg        la-fuente-bailey-deli-bronx-2
# 10  KBJjn-BNqkcEhqz_iaadWw             the-cumin-bowl-the-bronx
# 11  iBAQUuLjc3MJBjgN-kWwbw              yangs-corner-deli-bronx
# 12  OxKuzDIavYrwgkJk3UkXUg               super-sonic-suds-bronx
# 13  wplMK-nfPgNyK1aKySDeNA                     kuchifrito-bronx
# 14  e9xvJsf4r7d4mElmi7olIw   petropolis-bar-and-resturant-bronx
#
#                                     name  \
# 0                        Picante Picante
# 1                     Louie's Dale Diner
# 2                 Broadway Pizza & Pasta
# 3               Mei Chung Mei Restaurant
# 4                       Papa Johns Pizza
# 5   Bailey Seafood Kuchifrito Restaurant
# 6                          Laura's Pizza
# 7              New Adventure Mini Market
# 8                       Dough Boys Pizza
# 9                  La Fuente Bailey Deli
# 10                        The Cumin Bowl
# 11                    Yang's Corner Deli
# 12                      Super Sonic Suds
# 13                            Kuchifrito
# 14            Petropolis Bar & Resturant
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/Q9v9jq...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/6FDS3L...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/hNQ0Ml...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/HcrAZy...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/hdHwb5...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/U-lfEJ...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/CvR7ol...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/2lD277...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/OZ5Wya...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/a3Xloe...      False
# 10                                                         False
# 11                                                         False
# 12                                                         False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/Mi3mlW...      False
# 14                                                         False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/picante-picante-bronx...           196
# 1   https://www.yelp.com/biz/louies-dale-diner-bro...           148
# 2   https://www.yelp.com/biz/broadway-pizza-and-pa...            61
# 3   https://www.yelp.com/biz/mei-chung-mei-restaur...            30
# 4   https://www.yelp.com/biz/papa-johns-pizza-bron...            26
# 5   https://www.yelp.com/biz/bailey-seafood-and-ku...            11
# 6   https://www.yelp.com/biz/lauras-pizza-bronx-2?...            10
# 7   https://www.yelp.com/biz/new-adventure-mini-ma...             5
# 8   https://www.yelp.com/biz/dough-boys-pizza-bron...             4
# 9   https://www.yelp.com/biz/la-fuente-bailey-deli...             2
# 10  https://www.yelp.com/biz/the-cumin-bowl-the-br...             1
# 11  https://www.yelp.com/biz/yangs-corner-deli-bro...             0
# 12  https://www.yelp.com/biz/super-sonic-suds-bron...             0
# 13  https://www.yelp.com/biz/kuchifrito-bronx?adju...             0
# 14  https://www.yelp.com/biz/petropolis-bar-and-re...             0
#
#                                            categories  rating  \
# 0          [{'alias': 'mexican', 'title': 'Mexican'}]     3.8
# 1   [{'alias': 'diners', 'title': 'Diners'}, {'ali...     3.6
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.2
# 3          [{'alias': 'chinese', 'title': 'Chinese'}]     4.2
# 4   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     1.8
# 5   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     2.1
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     3.3
# 7          [{'alias': 'spanish', 'title': 'Spanish'}]     3.4
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 9   [{'alias': 'breakfast_brunch', 'title': 'Break...     3.0
# 10           [{'alias': 'indpak', 'title': 'Indian'}]     1.0
# 11             [{'alias': 'delis', 'title': 'Delis'}]     0.0
# 12  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
# 13     [{'alias': 'dominican', 'title': 'Dominican'}]     0.0
# 14  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
#
#                                           coordinates        transactions  \
# 0         {'latitude': 40.8781, 'longitude': -73.903}  [pickup, delivery]
# 1   {'latitude': 40.87883625432833, 'longitude': -...  [pickup, delivery]
# 2   {'latitude': 40.8786416169554, 'longitude': -7...  [pickup, delivery]
# 3   {'latitude': 40.8784523010254, 'longitude': -7...          [delivery]
# 4   {'latitude': 40.8784763, 'longitude': -73.9029...  [pickup, delivery]
# 5   {'latitude': 40.8780142, 'longitude': -73.9027...  [pickup, delivery]
# 6   {'latitude': 40.8776043355465, 'longitude': -7...  [pickup, delivery]
# 7               {'latitude': None, 'longitude': None}                  []
# 8   {'latitude': 40.8779404, 'longitude': -73.9027...                  []
# 9      {'latitude': 40.87807, 'longitude': -73.90288}  [pickup, delivery]
# 10  {'latitude': 40.8780142, 'longitude': -73.9027...  [pickup, delivery]
# 11  {'latitude': 40.8783302307129, 'longitude': -7...            [pickup]
# 12  {'latitude': 40.8782182, 'longitude': -73.9033...                  []
# 13  {'latitude': 40.8780957297452, 'longitude': -7...                  []
# 14        {'latitude': 40.8781, 'longitude': -73.903}            [pickup]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '156 W 231st St', 'address2': '',...  +17187087100
# 1     $$  {'address1': '189 W 231st St', 'address2': '',...  +17185494445
# 2      $  {'address1': '192 W 231st St', 'address2': '',...  +17186015000
# 3     $$  {'address1': '157 W 231st St', 'address2': '',...  +17185496719
# 4      $  {'address1': '161 W 231st St', 'address2': '',...  +17186017272
# 5    $$$  {'address1': '146 W 231st St', 'address2': '',...  +13479646295
# 6      $  {'address1': '3073 Bailey Ave', 'address2': No...  +17184321313
# 7     $$  {'address1': '161 West 231st St', 'address2': ...  +13478438800
# 8    NaN  {'address1': '3073 Bailey Ave', 'address2': No...  +17187085830
# 9    NaN  {'address1': '148 W 231 St', 'address2': None,...  +13473268690
# 10   NaN  {'address1': '146 W 231st St', 'address2': '',...
# 11   NaN  {'address1': '141 W 231st St', 'address2': '',...  +17185480679
# 12   NaN  {'address1': '166 W 231st St', 'address2': Non...  +17185482222
# 13   NaN  {'address1': '146 W 231st St', 'address2': '',...  +13479646296
# 14   NaN  {'address1': '156 W 231st St', 'address2': '',...  +17186012727
#
#      display_phone    distance  \
# 0   (718) 708-7100   26.110876
# 1   (718) 549-4445  104.821229
# 2   (718) 601-5000  106.502701
# 3   (718) 549-6719   24.229458
# 4   (718) 601-7272   23.280068
# 5   (347) 964-6295   37.251412
# 6   (718) 432-1313   81.889496
# 7   (347) 843-8800   19.719515
# 8   (718) 708-5830   51.437453
# 9   (347) 326-8690   35.310410
# 10                   37.251412
# 11  (718) 548-0679   43.936462
# 12  (718) 548-2222   19.214485
# 13  (347) 964-6296   30.893755
# 14  (718) 601-2727   26.110876
#
#                                            attributes
# 0   {'business_temp_closed': None, 'menu_url': 'ht...
# 1   {'business_temp_closed': None, 'menu_url': '',...
# 2   {'business_temp_closed': None, 'menu_url': Non...
# 3   {'business_temp_closed': None, 'menu_url': Non...
# 4   {'business_temp_closed': None, 'menu_url': 'ht...
# 5   {'business_temp_closed': None, 'menu_url': Non...
# 6   {'business_temp_closed': None, 'menu_url': '',...
# 7   {'business_temp_closed': None, 'menu_url': Non...
# 8   {'business_temp_closed': None, 'menu_url': Non...
# 9   {'business_temp_closed': None, 'menu_url': Non...
# 10  {'business_temp_closed': None, 'menu_url': Non...
# 11  {'business_temp_closed': None, 'menu_url': Non...
# 12  {'business_temp_closed': None, 'menu_url': Non...
# 13  {'business_temp_closed': None, 'menu_url': Non...
# 14  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: PAPA JOHN'S, Latitude: 40.878302535968, Longitude: -73.903151774701 has been uploaded to Google Cloud Storage.
# TACOS EL PAISANITO RESTAURANT
# Business data found:
#                        id                              alias  \
# 0  Gc1IwjWFF9wiiZt23OkDrg  number-8-chinese-restaurant-bronx
# 1  vyvpY_YfedXCyoSc2VxcNw        adonai-deli-grocery-bronx-2
#
#                           name  \
# 0  Number 8 Chinese Restaurant
# 1          Adonai Deli Grocery
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/iIG_7c...      False
# 1                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/number-8-chinese-rest...             6
# 1  https://www.yelp.com/biz/adonai-deli-grocery-b...             0
#
#                                           categories  rating  \
# 0         [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 1  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     0.0
#
#                                          coordinates        transactions  \
# 0      {'latitude': 40.8626, 'longitude': -73.90872}          [delivery]
# 1  {'latitude': 40.8625984, 'longitude': -73.9086...  [delivery, pickup]
#
#                                             location         phone  \
# 0  {'address1': '176 W Fordham Rd', 'address2': '...  +17187419998
# 1  {'address1': '174 W Fordham Rd', 'address2': '...  +13472719767
#
#     display_phone   distance  \
# 0  (718) 741-9998  62.846295
# 1  (347) 271-9767  69.014491
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': Non...
# 1  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: TACOS EL PAISANITO RESTAURANT, Latitude: 40.862580267137, Longitude: -73.909309943061 has been uploaded to Google Cloud Storage.
# MENCHIES
# Business data found:
#                         id                                   alias  \
# 0   5qF6oqYOeivUbsVf1MsQAA                        aoyu-sushi-bronx
# 1   gOxnVrGfRi55FqYMI7h9XQ                     bella-notte-bronx-3
# 2   aidZpXrufp3t-cV1tMTzOQ                            metate-bronx
# 3   py1zfy48JMV6tMZRvgxMKA                   palace-of-japan-bronx
# 4   Bcxs7yhP_G801lJEE1FXUg                       moss-cafe-bronx-2
# 5   BJn68qCExYQrPCT7CeOpzw               moon-star-grill-riverdale
# 6   6JNvLxm0PqgiuoiSXC9OOg            neem-indian-cuisine-new-york
# 7   aSP425EszrqRECIGDmdTWw                     pizza-chef-bronx-95
# 8   1ahP9qyZe95hX9z9ha-Bog                             anise-bronx
# 9   bTH0uaDCDhdTJ59q0kFOLg         the-johnson-diner-and-bar-bronx
# 10  maWBktJOshxn42uLa4jb5w                      johnson-deli-bronx
# 11  _rz0yaLx0lcoUypxnEIf2Q                         subway-bronx-92
# 12  GqMzgAmVDn7gjgcCJpVkFA  second-helping-glatt-kosher-food-bronx
# 13  J_0Be4qLunnk2pA4l13xMg  golden-gate-chinese-restaurant-bronx-2
# 14  n3xpF9lLsmMsEBz-iUXT3A               josepina-restaurant-bronx
# 15  aqS085Am2288Xlmq7gHXDQ                      wang-kun-lun-bronx
#
#                                 name  \
# 0                         Aoyu Sushi
# 1                        Bella Notte
# 2                             Metate
# 3                    Palace of Japan
# 4                          Moss Cafe
# 5                    Moon Star Grill
# 6                Neem Indian Cuisine
# 7                         Pizza Chef
# 8                              Anise
# 9            The Johnson Diner & Bar
# 10                      Johnson Deli
# 11                            Subway
# 12  Second Helping Glatt Kosher Food
# 13    Golden Gate Chinese Restaurant
# 14               Josepina Restaurant
# 15                      Wang Kun Lun
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/zY0dYQ...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/JwTMNF...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/fXDcVy...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/qw8v3h...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/93nSkE...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/cYH99R...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/G28Cgd...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/ztbaPE...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/cEQlbf...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/xldJR8...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/sg2uQg...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/YJxksn...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/_jIeio...      False
# 13                                                         False
# 14                                                         False
# 15                                                         False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/aoyu-sushi-bronx?adju...           322
# 1   https://www.yelp.com/biz/bella-notte-bronx-3?a...           237
# 2   https://www.yelp.com/biz/metate-bronx?adjust_c...           212
# 3   https://www.yelp.com/biz/palace-of-japan-bronx...           208
# 4   https://www.yelp.com/biz/moss-cafe-bronx-2?adj...           190
# 5   https://www.yelp.com/biz/moon-star-grill-river...           139
# 6   https://www.yelp.com/biz/neem-indian-cuisine-n...           109
# 7   https://www.yelp.com/biz/pizza-chef-bronx-95?a...            76
# 8   https://www.yelp.com/biz/anise-bronx?adjust_cr...            58
# 9   https://www.yelp.com/biz/the-johnson-diner-and...            27
# 10  https://www.yelp.com/biz/johnson-deli-bronx?ad...            13
# 11  https://www.yelp.com/biz/subway-bronx-92?adjus...            11
# 12  https://www.yelp.com/biz/second-helping-glatt-...             9
# 13  https://www.yelp.com/biz/golden-gate-chinese-r...             0
# 14  https://www.yelp.com/biz/josepina-restaurant-b...             0
# 15  https://www.yelp.com/biz/wang-kun-lun-bronx?ad...             0
#
#                                            categories  rating  \
# 0   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.4
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.7
# 2          [{'alias': 'mexican', 'title': 'Mexican'}]     3.1
# 3   [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.6
# 4   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     3.7
# 5   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     3.8
# 6   [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.2
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 8   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.9
# 9   [{'alias': 'diners', 'title': 'Diners'}, {'ali...     4.2
# 10  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.8
# 11  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     2.6
# 12             [{'alias': 'delis', 'title': 'Delis'}]     3.7
# 13  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
# 14  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
# 15         [{'alias': 'chinese', 'title': 'Chinese'}]     0.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 40.8860150724649, 'longitude': -7...  [pickup, delivery]
# 1    {'latitude': 40.886035, 'longitude': -73.909539}  [pickup, delivery]
# 2   {'latitude': 40.8860208, 'longitude': -73.9100...  [pickup, delivery]
# 3         {'latitude': 40.88612, 'longitude': -73.91}  [pickup, delivery]
# 4   {'latitude': 40.88529937379742, 'longitude': -...  [pickup, delivery]
# 5   {'latitude': 40.8861089331436, 'longitude': -7...  [pickup, delivery]
# 6    {'latitude': 40.886547, 'longitude': -73.909968}  [pickup, delivery]
# 7   {'latitude': 40.885555267334, 'longitude': -73...  [pickup, delivery]
# 8   {'latitude': 40.8859701, 'longitude': -73.9100...  [pickup, delivery]
# 9    {'latitude': 40.886399, 'longitude': -73.910039}  [pickup, delivery]
# 10  {'latitude': 40.88575747282374, 'longitude': -...  [pickup, delivery]
# 11  {'latitude': 40.88558755562703, 'longitude': -...  [pickup, delivery]
# 12     {'latitude': 40.88626, 'longitude': -73.90961}  [pickup, delivery]
# 13     {'latitude': 40.88648, 'longitude': -73.90954}                  []
# 14     {'latitude': 40.88611, 'longitude': -73.90967}            [pickup]
# 15     {'latitude': 40.88621, 'longitude': -73.90997}            [pickup]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '3532 A Johnson Ave', 'address2':...  +17188846633
# 1     $$  {'address1': '3524 Johnson Ave', 'address2': '...  +17188841666
# 2     $$  {'address1': '3515 Johnson Ave', 'address2': '...  +17185434444
# 3     $$  {'address1': '3505 Johnson Ave', 'address2': '...  +17185438833
# 4     $$  {'address1': '3260 Johnson Ave', 'address2': '...  +13472755000
# 5     $$  {'address1': '3519-25 Johnson Ave', 'address2'...  +17184322570
# 6     $$  {'address1': '3549 Johnson Ave', 'address2': N...  +13474273953
# 7      $  {'address1': '564 W 235th St', 'address2': '',...  +17187964500
# 8    NaN  {'address1': '3511 Johnson Ave', 'address2': '...  +17185430500
# 9     $$  {'address1': '35-33 Johnson Ave', 'address2': ...  +13156777665
# 10   NaN  {'address1': '561 W 235th St', 'address2': '',...  +17186841045
# 11     $  {'address1': '3526 Johnson Ave', 'address2': '...  +13476028581
# 12    $$  {'address1': '3532 Johnson Ave', 'address2': '...  +17185481818
# 13   NaN  {'address1': '3550 Johnson Ave', 'address2': '...  +17185496206
# 14   NaN  {'address1': '3522 Johnson Ave', 'address2': '...  +17187967997
# 15   NaN  {'address1': '3519 Johnson Ave', 'address2': N...  +17187960800
#
#      display_phone   distance  \
# 0   (718) 884-6633  19.557422
# 1   (718) 884-1666  28.770047
# 2   (718) 543-4444  25.129211
# 3   (718) 543-8833  35.856445
# 4   (347) 275-5000  98.807430
# 5   (718) 432-2570  11.072186
# 6   (347) 427-3953  33.876258
# 7   (718) 796-4500  81.247905
# 8   (718) 543-0500  27.234035
# 9   (315) 677-7665  27.370998
# 10  (718) 684-1045  58.759740
# 11  (347) 602-8581  75.122300
# 12  (718) 548-1818  27.465187
# 13  (718) 549-6206  43.930106
# 14  (718) 796-7997  15.859725
# 15  (718) 796-0800  25.970332
#
#                                            attributes
# 0   {'business_temp_closed': None, 'menu_url': 'ht...
# 1   {'business_temp_closed': None, 'menu_url': 'ht...
# 2   {'business_temp_closed': None, 'menu_url': Non...
# 3   {'business_temp_closed': None, 'menu_url': Non...
# 4   {'business_temp_closed': None, 'menu_url': Non...
# 5   {'business_temp_closed': None, 'menu_url': 'ht...
# 6   {'business_temp_closed': None, 'menu_url': 'ht...
# 7   {'business_temp_closed': None, 'menu_url': 'ht...
# 8   {'business_temp_closed': None, 'menu_url': 'ht...
# 9   {'business_temp_closed': None, 'menu_url': Non...
# 10  {'business_temp_closed': None, 'menu_url': Non...
# 11  {'business_temp_closed': None, 'menu_url': 'ht...
# 12  {'business_temp_closed': None, 'menu_url': Non...
# 13  {'business_temp_closed': None, 'menu_url': Non...
# 14  {'business_temp_closed': None, 'menu_url': Non...
# 15  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: MENCHIES, Latitude: 40.886182573208, Longitude: -73.909820111173 has been uploaded to Google Cloud Storage.
# MAMA'S BAKERY
# Business data found:
#                        id                                      alias  \
# 0  TcX3VlbQMVw8zoZzEeNREQ    fordham-fried-seafood-and-chicken-bronx
# 1  nDQ9sL87TLzMhAzkIQQZng                tacos-el-chuleton-the-bronx
# 2  HV8YNoH7FHWI1gW4OmBAdA                tenochtitlan-taqueria-bronx
# 3  NCElJVk74KVk24bAcm2V4w        bobos-crab-shack-fordham-new-york-5
# 4  5yIOTs5F11ksyqMDLuxf3A                      good-taste-new-york-5
# 5  ZuyFjvlwlvplisCnF4wO2w                         tropilyz-the-bronx
# 6  l7ij-mL9XUoLeHUn0u_hrg                   drug-rite-pharmacy-bronx
# 7  WXvQupc8-raPQxr_L_or9g  delicias-restaurant-and-sea-food-new-york
#
#                                 name  \
# 0  Fordham Fried Seafood And Chicken
# 1                  Tacos El Chuleton
# 2              Tenochtitlan Taqueria
# 3        Bobo's Crab Shack - Fordham
# 4                         Good Taste
# 5                           Tropilyz
# 6                 Drug Rite Pharmacy
# 7   Delicias Restaurant and Sea Food
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/f6k7cq...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/fSr7X-...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/rk-Mc4...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/f1m4VD...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/TIDMaX...      False
# 5  https://s3-media1.fl.yelpcdn.com/bphoto/yWlPUA...      False
# 6                                                         False
# 7                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/fordham-fried-seafood...            27
# 1  https://www.yelp.com/biz/tacos-el-chuleton-the...            21
# 2  https://www.yelp.com/biz/tenochtitlan-taqueria...            10
# 3  https://www.yelp.com/biz/bobos-crab-shack-ford...             5
# 4  https://www.yelp.com/biz/good-taste-new-york-5...             4
# 5  https://www.yelp.com/biz/tropilyz-the-bronx?ad...             3
# 6  https://www.yelp.com/biz/drug-rite-pharmacy-br...             0
# 7  https://www.yelp.com/biz/delicias-restaurant-a...             0
#
#                                           categories  rating  \
# 0  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     4.0
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]     3.1
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]     3.6
# 3  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     2.8
# 4   [{'alias': 'tradamerican', 'title': 'American'}]     2.0
# 5  [{'alias': 'dominican', 'title': 'Dominican'},...     3.0
# 6  [{'alias': 'drugstores', 'title': 'Drugstores'...     0.0
# 7  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     0.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.8615512, 'longitude': -73.897185}  [pickup, delivery]
# 1     {'latitude': 40.86014, 'longitude': -73.89876}  [pickup, delivery]
# 2  {'latitude': 40.861599, 'longitude': -73.8989334}          [delivery]
# 3     {'latitude': 40.86102, 'longitude': -73.89753}  [pickup, delivery]
# 4  {'latitude': 40.86147667, 'longitude': -73.898...          [delivery]
# 5     {'latitude': 40.86148, 'longitude': -73.89728}  [pickup, delivery]
# 6     {'latitude': 40.86036, 'longitude': -73.89788}                  []
# 7     {'latitude': 40.86069, 'longitude': -73.89847}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '2468 Grand Concourse', 'address2...  +17189339854
# 1   NaN  {'address1': '2399 Grand Concourse', 'address2...  +17186765880
# 2     $  {'address1': '2445 Creston Ave', 'address2': '...  +16466647875
# 3   NaN  {'address1': '2450 Grand Concourse', 'address2...  +19178010833
# 4   NaN  {'address1': '2428 Creston Ave', 'address2': N...  +17189338888
# 5   NaN  {'address1': '2462 Grand Concourse', 'address2...
# 6   NaN  {'address1': '2426 Grand Concourse', 'address2...  +17182209200
# 7   NaN  {'address1': '2419 Grand Concourse', 'address2...  +17189757065
#
#     display_phone    distance  \
# 0  (718) 933-9854  114.386336
# 1  (718) 676-5880   87.393740
# 2  (646) 664-7875  119.712824
# 3  (917) 801-0833   52.853347
# 4  (718) 933-8888   95.362170
# 5                  104.531088
# 6  (718) 220-9200   42.316863
# 7  (718) 975-7065   35.893696
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': Non...
# 1  {'business_temp_closed': None, 'menu_url': Non...
# 2  {'business_temp_closed': None, 'menu_url': Non...
# 3  {'business_temp_closed': None, 'menu_url': 'ht...
# 4  {'business_temp_closed': None, 'menu_url': Non...
# 5  {'business_temp_closed': None, 'menu_url': Non...
# 6  {'business_temp_closed': None, 'menu_url': Non...
# 7  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: MAMA'S BAKERY, Latitude: 40.860764808457, Longitude: -73.898061886322 has been uploaded to Google Cloud Storage.
# EL FOGON KITCHEN
# Business data found:
#                        id                                 alias  \
# 0  ZwRNSNephTpuEDpmED26Kg                don-emilio-diner-bronx
# 1  JGhsGLRWe_ABz9uM2woEkg              hilltop-restaurant-bronx
# 2  MDc5PIAWenUcIWoiNCz1Tw  el-fogon-dominican-kitchen-the-bronx
# 3  GlBa24pwQthoXmMD75Bahg                         maculai-bronx
# 4  nkau8U5Z48-dl4ICQZBDRw       big-american-gourmet-deli-bronx
# 5  h7APwMILQ80MHaeq43fHQA         kennedys-fried-chickens-bronx
# 6  Vjoss2Qc8WruyQXdMsOf5A             hill-top-restaurant-bronx
# 7  bF5j32eDmq0qw0zQr7Ai8A                        yko-fish-bronx
#
#                          name  \
# 0            Don Emilio Diner
# 1          Hilltop Restaurant
# 2  El Fogon Dominican Kitchen
# 3                     Maculai
# 4   Big American Gourmet Deli
# 5    Kennedy's Fried Chickens
# 6         Hill Top Restaurant
# 7                    Yko Fish
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/MUuUZz...      False
# 1                                                         False
# 2                                                         False
# 3                                                         False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/vyT9yO...      False
# 5                                                         False
# 6                                                         False
# 7                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/don-emilio-diner-bron...            31
# 1  https://www.yelp.com/biz/hilltop-restaurant-br...             7
# 2  https://www.yelp.com/biz/el-fogon-dominican-ki...             7
# 3  https://www.yelp.com/biz/maculai-bronx?adjust_...             1
# 4  https://www.yelp.com/biz/big-american-gourmet-...             1
# 5  https://www.yelp.com/biz/kennedys-fried-chicke...             0
# 6  https://www.yelp.com/biz/hill-top-restaurant-b...             0
# 7  https://www.yelp.com/biz/yko-fish-bronx?adjust...             0
#
#                                           categories  rating  \
# 0     [{'alias': 'dominican', 'title': 'Dominican'}]     3.6
# 1  [{'alias': 'restaurants', 'title': 'Restaurant...     2.9
# 2     [{'alias': 'dominican', 'title': 'Dominican'}]     2.6
# 3       [{'alias': 'filipino', 'title': 'Filipino'}]     2.0
# 4  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     5.0
# 5  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
# 6  [{'alias': 'newamerican', 'title': 'New Americ...     0.0
# 7         [{'alias': 'seafood', 'title': 'Seafood'}]     0.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.8352414873058, 'longitude': -7...  [delivery, pickup]
# 1      {'latitude': 40.83464, 'longitude': -73.8516}  [delivery, pickup]
# 2  {'latitude': 40.8353409531807, 'longitude': -7...  [delivery, pickup]
# 3  {'latitude': 40.8347187, 'longitude': -73.8520...                  []
# 4  {'latitude': 40.83577705028105, 'longitude': -...  [delivery, pickup]
# 5      {'latitude': 40.8344, 'longitude': -73.85126}            [pickup]
# 6      {'latitude': 40.83464, 'longitude': -73.8516}                  []
# 7     {'latitude': 40.83458, 'longitude': -73.85146}                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '1315 Castle Hill Ave', 'address2...  +17186842827
# 1     $  {'address1': '1306 Castle Hill Ave', 'address2...  +17184090412
# 2   NaN  {'address1': '1368 Castle Hill Ave', 'address2...  +17188232601
# 3   NaN  {'address1': '1317 Castlehill Ave', 'address2'...
# 4   NaN  {'address1': '1400 Castle Hill Ave', 'address2...  +17186841423
# 5   NaN  {'address1': '2215 Westchester Ave', 'address2...  +17187945164
# 6   NaN  {'address1': '1306 Castle Hill Ave', 'address2...  +13473989799
# 7   NaN  {'address1': '2211 Westchester Ave', 'address2...  +17188929521
#
#     display_phone    distance  \
# 0  (718) 684-2827   17.979276
# 1  (718) 409-0412   77.300113
# 2  (718) 823-2601   25.472642
# 3                   77.951490
# 4  (718) 684-1423   57.166392
# 5  (718) 794-5164  113.924189
# 6  (347) 398-9799   77.300113
# 7  (718) 892-9521  108.435208
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': Non...
# 1  {'business_temp_closed': None, 'menu_url': Non...
# 2  {'business_temp_closed': None, 'menu_url': Non...
# 3  {'business_temp_closed': None, 'menu_url': Non...
# 4  {'business_temp_closed': None, 'menu_url': Non...
# 5  {'business_temp_closed': None, 'menu_url': Non...
# 6  {'business_temp_closed': None, 'menu_url': Non...
# 7  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: EL FOGON KITCHEN, Latitude: 40.835265473986, Longitude: -73.851967038504 has been uploaded to Google Cloud Storage.
# YOL Y RESTAURANT
# Business data found:
#                        id                             alias  \
# 0  gWwGJj3MvU-WGNqrSqLecg       xing-sheng-restaurant-bronx
# 1  I84nL3rBNNu2n0FyAVswmg             kennedy-chicken-bronx
# 2  IFXOCz4XwZciSwbzDTuRSA             seafood-house-2-bronx
# 3  1obkh5buOv69ExwknV4vPg  dkjj-deli-food-corporation-bronx
# 4  bA0vPSb25WyRYRAPKEDZ0Q     la-gran-parada-criollla-bronx
# 5  enbsXdebQFzktAUfUD_tNQ             featherbed-food-bronx
# 6  0el9bBQ6OQF8hLAbXwI1bQ       tamborile-corporation-bronx
#
#                          name  \
# 0       Xing Sheng Restaurant
# 1             Kennedy Chicken
# 2             Seafood House 2
# 3  Dkjj Deli Food Corporation
# 4     La Gran Parada Criollla
# 5             Featherbed Food
# 6       Tamborile Corporation
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/VHa2mY...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/bTHYP1...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/Qbx-e2...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/Pp3xy0...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/6as3-9...      False
# 5                                                         False
# 6                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/xing-sheng-restaurant...             4
# 1  https://www.yelp.com/biz/kennedy-chicken-bronx...             3
# 2  https://www.yelp.com/biz/seafood-house-2-bronx...             3
# 3  https://www.yelp.com/biz/dkjj-deli-food-corpor...             1
# 4  https://www.yelp.com/biz/la-gran-parada-crioll...             0
# 5  https://www.yelp.com/biz/featherbed-food-bronx...             0
# 6  https://www.yelp.com/biz/tamborile-corporation...             0
#
#                                           categories  rating  \
# 0         [{'alias': 'chinese', 'title': 'Chinese'}]     3.3
# 1  [{'alias': 'restaurants', 'title': 'Restaurant...     3.7
# 2         [{'alias': 'seafood', 'title': 'Seafood'}]     4.7
# 3  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.0
# 4  [{'alias': 'juicebars', 'title': 'Juice Bars &...     0.0
# 5       [{'alias': 'hotdogs', 'title': 'Fast Food'}]     0.0
# 6  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
#
#                                          coordinates        transactions  \
# 0     {'latitude': 40.84638, 'longitude': -73.91892}          [delivery]
# 1      {'latitude': 40.84603, 'longitude': -73.9201}  [pickup, delivery]
# 2  {'latitude': 40.84612456034338, 'longitude': -...          [delivery]
# 3  {'latitude': 40.84669149160617, 'longitude': -...            [pickup]
# 4  {'latitude': 40.8467106, 'longitude': -73.9204...                  []
# 5   {'latitude': 40.845906, 'longitude': -73.920179}                  []
# 6   {'latitude': 40.8459999, 'longitude': -73.91998}            [pickup]
#
#                                             location         phone  \
# 0  {'address1': '115 Featherbed Ln', 'address2': ...  +17182992336
# 1  {'address1': '124 Featherbed Ln', 'address2': ...  +17187314314
# 2  {'address1': '140  Featherbed Ln', 'address2':...  +19179629701
# 3  {'address1': '1584 Dr Martin L King Jr Blvd', ...  +17186760820
# 4  {'address1': '1586 University Ave', 'address2'...  +13472702464
# 5  {'address1': '120 Featherbed Ln', 'address2': ...  +17184508486
# 6  {'address1': '118 Featherbed Ln', 'address2': ...  +17187315900
#
#     display_phone   distance  \
# 0  (718) 299-2336  84.463161
# 1  (718) 731-4314  24.657444
# 2  (917) 962-9701  55.266871
# 3  (718) 676-0820  86.860161
# 4  (347) 270-2464  85.771635
# 5  (718) 450-8486  25.823838
# 6  (718) 731-5900  15.020641
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': Non...
# 1  {'business_temp_closed': None, 'menu_url': Non...
# 2  {'business_temp_closed': None, 'menu_url': Non...
# 3  {'business_temp_closed': None, 'menu_url': Non...
# 4  {'business_temp_closed': None, 'menu_url': Non...
# 5  {'business_temp_closed': None, 'menu_url': Non...
# 6  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: YOL Y RESTAURANT, Latitude: 40.846081276411, Longitude: -73.919850460097 has been uploaded to Google Cloud Storage.
# OUTBACK STEAKHOUSE
# No business data found in the response.
# LINDA'S PIZZA
# Business data found:
#                        id                                  alias  \
# 0  dI9UM-fXCaXD3quU71m-XA                cosmos-restaurant-bronx
# 1  oDgUIxXri1RmOQVnH0_qCA  jj-restaurant-and-cuchifritos-bronx-3
# 2  _3KZcY3apoAwH_9wTXp4OQ                   lindas-pizza-bronx-2
# 3  -lZVfL-OtBki2U3Tv-mRNw                      alexs-tacos-bronx
# 4  Iya5oeNoVQuELO2NUBb7UQ                      checkers-bronx-10
# 5  c1TysFP9MyZ3EpkvtxElxA                  nice-restaurant-bronx
# 6  KB6vsMXKFZRhzA1v-dNoAA        galaxy-chinese-restaurant-bronx
# 7  t6VNi8zYL6o53-2KsbyoSQ         clinton-deli-and-grocery-bronx
#
#                           name  \
# 0           Cosmo's Restaurant
# 1  JJ Restaurant & Cuchifritos
# 2                Linda's Pizza
# 3                 Alex's Tacos
# 4                     Checkers
# 5              Nice Restaurant
# 6    Galaxy Chinese Restaurant
# 7       Clinton Deli & Grocery
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/1i2kZZ...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/HbAm2c...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/zyfI8v...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/C1I9Nn...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/1LKLMQ...      False
# 5                                                         False
# 6                                                         False
# 7                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/cosmos-restaurant-bro...            28
# 1  https://www.yelp.com/biz/jj-restaurant-and-cuc...            26
# 2  https://www.yelp.com/biz/lindas-pizza-bronx-2?...            23
# 3  https://www.yelp.com/biz/alexs-tacos-bronx?adj...            17
# 4  https://www.yelp.com/biz/checkers-bronx-10?adj...             3
# 5  https://www.yelp.com/biz/nice-restaurant-bronx...             0
# 6  https://www.yelp.com/biz/galaxy-chinese-restau...             0
# 7  https://www.yelp.com/biz/clinton-deli-and-groc...             0
#
#                                           categories  rating  \
# 0           [{'alias': 'diners', 'title': 'Diners'}]     4.5
# 1         [{'alias': 'spanish', 'title': 'Spanish'}]     2.5
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     3.2
# 3  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.4
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 5  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
# 6         [{'alias': 'chinese', 'title': 'Chinese'}]     0.0
# 7  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 40.84481, 'longitude': -73.890337}          [delivery]
# 1   {'latitude': 40.844966, 'longitude': -73.890611}  [pickup, delivery]
# 2     {'latitude': 40.84507, 'longitude': -73.89014}  [pickup, delivery]
# 3  {'latitude': 40.8445633970481, 'longitude': -7...  [pickup, delivery]
# 4   {'latitude': 40.845355, 'longitude': -73.890534}  [pickup, delivery]
# 5      {'latitude': 40.84453, 'longitude': -73.8896}            [pickup]
# 6  {'latitude': 40.8454666137695, 'longitude': -7...                  []
# 7      {'latitude': 40.84517, 'longitude': -73.8909}            [pickup]
#
#   price                                           location         phone  \
# 0     $  {'address1': '726 E Tremont Ave', 'address2': ...  +17182991925
# 1    $$  {'address1': '718 E Tremont Ave', 'address2': ...  +17185833333
# 2     $  {'address1': '729 E Tremont Ave', 'address2': ...  +17185834282
# 3     $  {'address1': '744 E Tremont Ave', 'address2': ...  +19178916910
# 4   NaN  {'address1': '711 E Tremont Ave', 'address2': ...  +13478798756
# 5   NaN  {'address1': '744 E Tremont Ave', 'address2': ...  +17187311166
# 6   NaN  {'address1': '707 E Tremont Ave', 'address2': ...  +17182993939
# 7   NaN  {'address1': '706 E Tremont Ave', 'address2': ...  +17182943465
#
#     display_phone   distance  \
# 0  (718) 299-1925  17.786022
# 1  (718) 583-3333  30.982041
# 2  (718) 583-4282  20.766581
# 3  (917) 891-6910  73.037382
# 4  (347) 879-8756  46.804761
# 5  (718) 731-1166  81.635694
# 6  (718) 299-3939  61.200647
# 7  (718) 294-3465  63.335418
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': Non...
# 1  {'business_temp_closed': None, 'menu_url': Non...
# 2  {'business_temp_closed': None, 'menu_url': Non...
# 3  {'business_temp_closed': None, 'menu_url': Non...
# 4  {'business_temp_closed': None, 'menu_url': Non...
# 5  {'business_temp_closed': None, 'menu_url': Non...
# 6  {'business_temp_closed': None, 'menu_url': Non...
# 7  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: LINDA'S PIZZA, Latitude: 40.844978129292, Longitude: -73.890243027742 has been uploaded to Google Cloud Storage.
# SHAHID RASUL
# No business data found in the response.
# MY PIZZA
# Business data found:
#                        id                                      alias  \
# 0  dwxT5nbSICKmGbqBfTtwrQ                         mcdonalds-bronx-64
# 1  HsR3CeK2Ca8b_Q8Rn8spnA                casa-clema-restaurant-bronx
# 2  OzKqzm73GGWh3yCNhqAfaw                       kennedys-the-bronx-2
# 3  FHuDi_Wxo6j-eUnRqlKGcg  u-s-kennedy-fried-chicken-and-pizza-bronx
#
#                                 name  \
# 0                         McDonald's
# 1              Casa Clema Restaurant
# 2                           Kennedys
# 3  U.S Kennedy Fried Chicken & Pizza
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/50iBBq...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/nG2yga...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/0gampI...      False
# 3                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/mcdonalds-bronx-64?ad...             9
# 1  https://www.yelp.com/biz/casa-clema-restaurant...             6
# 2  https://www.yelp.com/biz/kennedys-the-bronx-2?...             1
# 3  https://www.yelp.com/biz/u-s-kennedy-fried-chi...             1
#
#                                           categories  rating  \
# 0  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     1.1
# 1  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...     3.7
# 2  [{'alias': 'chicken_wings', 'title': 'Chicken ...     4.0
# 3  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     5.0
#
#                                          coordinates        transactions  \
# 0   {'latitude': 40.850258, 'longitude': -73.916202}          [delivery]
# 1  {'latitude': 40.8498016, 'longitude': -73.9168...  [pickup, delivery]
# 2     {'latitude': 40.85045, 'longitude': -73.91592}                  []
# 3     {'latitude': 40.85045, 'longitude': -73.91592}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '1745 University Ave', 'address2'...  +17182941309
# 1   NaN  {'address1': '1731 University Ave', 'address2'...  +17189012692
# 2   NaN  {'address1': '1761 University Ave', 'address2'...  +17187166430
# 3   NaN  {'address1': '1761 University Ave', 'address2'...
#
#     display_phone    distance  \
# 0  (718) 294-1309   79.900420
# 1  (718) 901-2692   35.594084
# 2  (718) 716-6430  110.426945
# 3                  110.426945
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': 'ht...
# 1  {'business_temp_closed': None, 'menu_url': Non...
# 2  {'business_temp_closed': None, 'menu_url': Non...
# 3  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: MY PIZZA, Latitude: 40.849630697925, Longitude: -73.916665314653 has been uploaded to Google Cloud Storage.
# CHINA WANG RESTAURANT
# Business data found:
#                        id                      alias                 name  \
# 0  jFIAhRS1qCTBM3AhncOKgg  arturos-pizzeria-new-york    Arturo's Pizzeria
# 1  nmu94WR4OY82i3jQoEWwXw  taqueria-sinaloense-bronx  Taqueria Sinaloense
# 2  30xGtjMKPPDD3C7BcKozdQ           china-wang-bronx           China Wang
# 3  KoUpkn_ww4ASFHhMqVdpeQ       garden-of-eden-bronx       Garden of Eden
# 4  KKWW2Y7q3lAiPPVVfWxnPg    marea-fish-market-bronx    Marea Fish Market
# 5  Q-FuFf_IWx9241CEAcrXGw         bronx-deli-bronx-2           Bronx Deli
# 6  IjHI6oSk_N7ZUGfPesLivw    kam-wah-kitchen-bronx-2      Kam Wah Kitchen
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/z5xb3-...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/rxHwX9...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/VG3h_d...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/Zs_2_x...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/5uAYl2...      False
# 5                                                         False
# 6                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/arturos-pizzeria-new-...           144
# 1  https://www.yelp.com/biz/taqueria-sinaloense-b...            26
# 2  https://www.yelp.com/biz/china-wang-bronx?adju...            14
# 3  https://www.yelp.com/biz/garden-of-eden-bronx?...             6
# 4  https://www.yelp.com/biz/marea-fish-market-bro...             3
# 5  https://www.yelp.com/biz/bronx-deli-bronx-2?ad...             0
# 6  https://www.yelp.com/biz/kam-wah-kitchen-bronx...             0
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     2.7
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]     4.4
# 2         [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 3   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     2.7
# 4         [{'alias': 'seafood', 'title': 'Seafood'}]     3.7
# 5  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     0.0
# 6  [{'alias': 'restaurants', 'title': 'Restaurant...     0.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 40.874438, 'longitude': -73.91042}  [delivery, pickup]
# 1  {'latitude': 40.8745319406573, 'longitude': -7...  [delivery, pickup]
# 2     {'latitude': 40.87453, 'longitude': -73.91061}  [delivery, pickup]
# 3     {'latitude': 40.87446, 'longitude': -73.91026}                  []
# 4  {'latitude': 40.875087, 'longitude': -73.9095518}  [delivery, pickup]
# 5   {'latitude': 40.87446, 'longitude': -73.9102599}                  []
# 6   {'latitude': 40.875091, 'longitude': -73.909622}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0     $  {'address1': '5189 Broadway', 'address2': '', ...  +17185623820
# 1   NaN  {'address1': '113 W 225th St', 'address2': Non...  +19172614146
# 2    $$  {'address1': '109 W 225th St', 'address2': '',...  +17183643831
# ...
# 5   NaN  {'address1': '3805 Dyre Ave Frnt 3', 'address2...  +13472025099
#
#     display_phone   distance  \
# 0  (718) 994-0036  37.628690
# 1  (718) 325-8770  46.740040
# 2  (718) 994-5544  17.977952
# 3  (347) 913-4288  14.465064
# 4  (718) 324-1014  65.030127
# 5  (347) 202-5099  34.694739
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': Non...
# 1  {'business_temp_closed': None, 'menu_url': Non...
# 2  {'business_temp_closed': None, 'menu_url': Non...
# 3  {'business_temp_closed': None, 'menu_url': Non...
# 4  {'business_temp_closed': None, 'menu_url': Non...
# 5  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: MARIO'S ITALIAN PIZZERIA, Latitude: 40.888248758972, Longitude: -73.831280331071 has been uploaded to Google Cloud Storage.
# CHARLIES BAR & KITCHEN
# Business data found:
#                        id             alias        name  \
# 0  8ofN8cBJd2oTmdbMzlY1zA  maisonetta-bronx  MAiSONETTA
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/yfYPRb...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/maisonetta-bronx?adju...            67
#
#                                           categories  rating  \
# 0  [{'alias': 'french', 'title': 'French'}, {'ali...     4.6
#
#                                         coordinates        transactions  \
# 0  {'latitude': 40.808704, 'longitude': -73.929127}  [delivery, pickup]
#
#                                             location         phone  \
# 0  {'address1': '141 Lincoln Ave', 'address2': No...  +13472974607
#
#     display_phone  distance                                         attributes
# 0  (347) 297-4607  95.10831  {'business_temp_closed': None, 'menu_url': Non...
# Restaurant: CHARLIES BAR & KITCHEN, Latitude: 40.807888973374, Longitude: -73.929393440715 has been uploaded to Google Cloud Storage.
# SBARRO
# No business data found in the response.
# KETOLAND & SERIE 54
# Request failed with status code: 429
# TACOS AZTECA
# Request failed with status code: 429
# BROTHER'S RESTAURANT
# Request failed with status code: 429
# CARIDAD RESTAURANT
# Request failed with status code: 429
# PIZZERIA SAN DIEGO
# Request failed with status code: 429
# FOO HING KITCHEN
# Request failed with status code: 429
# WENDY'S
# Request failed with status code: 429
# CODE RED
# Request failed with status code: 429
# METRO CAFE
# Request failed with status code: 429
# SUBWAY
# Request failed with status code: 429
# SANTA FE GRILL & BAR
# Request failed with status code: 429
# BETO'S RESTAURANT
# Request failed with status code: 429
# DUNKIN
# Request failed with status code: 429
# YOL Y RESTAURANT
# Request failed with status code: 429
# TWO GRANDPA'S PIZZA
# Request failed with status code: 429
# COUNTRY BOYZ
# Request failed with status code: 429
# EL PORTON BAR & MEXICAN RESTAURANT
# Request failed with status code: 429
# TWIN DONUTS
# Request failed with status code: 429
# AMINAS CAFE
# Request failed with status code: 429
# CHAMPION BAKERY
# Request failed with status code: 429
# DIPPIN' DOTS
# Request failed with status code: 429
# AMOR BAKERY NO 2
# Request failed with status code: 429
# LULU JUICY FRUIT
# Request failed with status code: 429
# WAVE HILL
# Request failed with status code: 429
# TEXAS CHICKEN & BURGER
# Request failed with status code: 429
# DUNKIN DONUTS
# Request failed with status code: 429
# GABI JUICE BAR
# Request failed with status code: 429
# UNICO TACOS BAR
# Request failed with status code: 429
# CHAMPION BAKERY
# Request failed with status code: 429
# BARESE PIZZA
# Request failed with status code: 429
# 99 CENT SUPREME PIZZA
# Request failed with status code: 429
# SIDEBAR CAFE
# Request failed with status code: 429
# NEW FLOWER CHINESE RESTAURANT
# Request failed with status code: 429
# COCINA CHENTE MEXICAN CUISINE
# Request failed with status code: 429
# TEXAS CHICKEN AND BURGERS
# Request failed with status code: 429
# LECHONERA Y POLLO SABROSO RESTAURANT
# Request failed with status code: 429
# CENTRO VIVA FELIZ
# Request failed with status code: 429
# WHITE CASTLE
# Request failed with status code: 429
# FRANK'S SOUP BOWL
# Request failed with status code: 429
# BEATSTRO
# Request failed with status code: 429
# AUNTIE ANNES
# Request failed with status code: 429
# CAPY
# Request failed with status code: 429
# SOLIMAR GRILL
# Request failed with status code: 429
# TCR CAFE
# Request failed with status code: 429
# 5 STAR PIZZA
# Request failed with status code: 429
# ALLERTON RESTAURANT
# Request failed with status code: 429
# STARBUCKS
# Request failed with status code: 429
# SUBWAY
# Request failed with status code: 429
# AROMA RESTAURAT & BAR
# Request failed with status code: 429
# LIBERATO RESTAURANT
# Request failed with status code: 429
# ENZO'S RESTAURANT
# Request failed with status code: 429
# GUACAMOLE MEXICAN GRILL
# Request failed with status code: 429
# EL VALLE RESTAURANT
# Request failed with status code: 429
# HOT PEPPERS
# Request failed with status code: 429
# MARINELL BAKERY
# Request failed with status code: 429
# ROCCOS PIZZA
# Request failed with status code: 429
# NO 1 LUCK SUNG RESTAURANT
# Request failed with status code: 429
# ESTRELLITA POBLANA # 1
# Request failed with status code: 429
# M AND G RESTAURANT
# Request failed with status code: 429
# Don Sazon Restaurant
# Request failed with status code: 429
# LINDA'S PIZZA
# Request failed with status code: 429
# WEBSTER CAFE
# Request failed with status code: 429
# LOS BALBUENA RESTAURANT
# Request failed with status code: 429
# MCMURRAY HALL (SUNY MARITIME)
# Request failed with status code: 429
# MORRIS PARK BAKE SHOP
# Request failed with status code: 429
# CALIENTE'S
# Request failed with status code: 429
# VENICE
# Request failed with status code: 429
# NEW CHINA RESTAURANT WANG
# Request failed with status code: 429
# JOHN'S DINER
# Request failed with status code: 429
# COCO PASTEL BAKERY
# Request failed with status code: 429
# SEAFOOD CITY
# Request failed with status code: 429
# FABENA PIZZA
# Request failed with status code: 429
# PANERA BREAD
# Request failed with status code: 429
# GRAND SLAM BANQUET HALL
# Request failed with status code: 429
# PASQUALE'S RIGOLETTO RESTAURANT
# Request failed with status code: 429
# HAPPY DRAGON
# Request failed with status code: 429
# KENNEDY FRIED CHICKEN
# Request failed with status code: 429
# JOE'S PIZZA
# Request failed with status code: 429
# PABELLON
# Request failed with status code: 429
# POPEYES
# Request failed with status code: 429
# #1 SABOR LATINO RESTAURANT
# Request failed with status code: 429
# CESTRA'S PIZZERIA & RESTAURANT
# Request failed with status code: 429
# BLANQUITA RESTAURANT
# Request failed with status code: 429
# EL VIEJO GRAN CAFE
# Request failed with status code: 429
# JUSTIN'S PIZZA
# Request failed with status code: 429
# PUGSLEY PIZZA
# Request failed with status code: 429
# ANGEL'S CAFE
# Request failed with status code: 429
# TEXAS CHICKEN & BURGER
# Request failed with status code: 429
# EL PATRON NIGHTCLUB CABARET-RESTAURANT
# Request failed with status code: 429
# DOWNEY'S BAR & GRILL
# Request failed with status code: 429
# CHUCK E. CHEESE'S
# Request failed with status code: 429
# MADISON'S DELICIOUS PIZZA CAFE
# Request failed with status code: 429
# THAI MAX
# Request failed with status code: 429
# LA PASTORA BAKERY
# Request failed with status code: 429
# TENARES RESTAURANT
# Request failed with status code: 429
# JEN'S FRENCH TOAST
# Request failed with status code: 429
# LOS MANGOS BAR & GRILL
# Request failed with status code: 429
# GIOVANNI RESTAURANT
# Request failed with status code: 429
# NEW BOE LEE
# Request failed with status code: 429
# NEW KENNEDY CHICKEN & GYRO
# Request failed with status code: 429
# GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# Request failed with status code: 429
# MENCHIES
# Request failed with status code: 429
# EL SAZON DE MI ABUELA
# Request failed with status code: 429
# SEIS VECINOS RESTAURANT
# Request failed with status code: 429
# DUNKIN
# Request failed with status code: 429
# JUICY KING CRAB EXPRESS
# Request failed with status code: 429
# LUNA CAFE
# Request failed with status code: 429
# DUNKIN
# Request failed with status code: 429
# PARKCHESTER FISH & CHIPS
# Request failed with status code: 429
# STARBUCKS
# Request failed with status code: 429
# LUNA CAFE
# Request failed with status code: 429
# STARBUCKS
# Request failed with status code: 429
# MCDONALD'S
# Request failed with status code: 429
# ELLIE'S DINER & RESTAURANT
# Request failed with status code: 429
# BETTER GOURMET HEALTH KITCHEN
# Request failed with status code: 429
# EL CARIDAD RESTAURANT
# Request failed with status code: 429
# DON EMILIO DINER RESTAURANT
# Request failed with status code: 429
# LOS CATRACHOS
# Request failed with status code: 429
# DUNKIN
# Request failed with status code: 429
# ROYAL CARIBBEAN BAKERY & RESTAURANT
# Request failed with status code: 429
# T-BROTHERS PIZZERIA
# Request failed with status code: 429
# ALLERTON RESTAURANT
# Request failed with status code: 429
# ESTRELLA BAR & RESTAURANT
# Request failed with status code: 429
# GINO'S PASTRY SHOP & CAFE
# Request failed with status code: 429
# CHRIS SUPER DELI
# Request failed with status code: 429
# LINCOLN HOT PIZZA
# Request failed with status code: 429
# DYNASTY TASTE LAM
# Request failed with status code: 429
# TACOS EL PAISANITO RESTAURANT
# Request failed with status code: 429
# WENDY'S
# Request failed with status code: 429
# GREAT WALL KITCHEN
# Request failed with status code: 429
# NEW GREEN DRAGON
# Request failed with status code: 429
# SIAM SQAURE THAI CUISINE
# Request failed with status code: 429
# KENNEDY FRIED CHICKEN
# Request failed with status code: 429
# BLIMPIE TWIN DONUT
# Request failed with status code: 429
# MCDONALD'S
# Request failed with status code: 429
# KENNEDY CHICKEN &SANDWICHES
# Request failed with status code: 429
# SNACK STATION
# Request failed with status code: 429
# KENNEDY FRIED CHICKEN
# Request failed with status code: 429
# PAPA JOHN'S PIZZA
# Request failed with status code: 429
# BRONX NUTRITION SPOT
# Request failed with status code: 429
# JEN'S FRENCH TOAST
# Request failed with status code: 429
# AGAVE RESTAURANT & LOUNGE
# Request failed with status code: 429
# KINGSBRIDGE COFFEE SHOP
# Request failed with status code: 429
# OLIVIA'S RESTAURANT & LOUNGE
# Request failed with status code: 429
# NYBG-HUDSON GARDEN GRILL-DAVID EDWARDS
# Request failed with status code: 429
# LEGENDS 100
# Request failed with status code: 429
# DYNASTY TASTE LAM
# Request failed with status code: 429
# KENNEDY FRIED CHICKEN
# Request failed with status code: 429
# XIME DELI
# Request failed with status code: 429
# R&N MOUNTAIN TOP RESTAURANT
# Request failed with status code: 429
# BASHA
# Request failed with status code: 429
# ANTHONY & SAL'S PIZZA EXPRESS
# Request failed with status code: 429
# FRANCO BAKERY
# Request failed with status code: 429
# 27 SPORTS BAR & CAFE
# Request failed with status code: 429
# AFRICAN HOME RESTAURANT
# Request failed with status code: 429
# TACOS EL PAISANITO RESTAURANT
# Request failed with status code: 429
# JESS TOWN AND COUNTRY CUISINE
# Request failed with status code: 429
# FOO-HING KITCHEN
# Request failed with status code: 429
# MR. CAKE BAKE SHOP
# Request failed with status code: 429
# MERRY LAND BUFFET
# Request failed with status code: 429
# El Crucero Restaurant & Grill
# Request failed with status code: 429
# SABANA LOUNGE
# Request failed with status code: 429
# KATONAH ITALIAN PASTRY SHOP
# Request failed with status code: 429
# COM TAM NINH KIEU
# Request failed with status code: 429
# Talavera Cantina
# Request failed with status code: 429
# EAZY LIFE RESTAURANT
# Request failed with status code: 429
# STARBUCKS
# Request failed with status code: 429
# ADDEOS OF THE BRONX
# Request failed with status code: 429
# SUPER KENNEDY FRIED CHICKEN
# Request failed with status code: 429
# AGAVE RESTAURANT & LOUNGE
# Request failed with status code: 429
# SUPER KENNEDY FRIED CHICKEN
# Request failed with status code: 429
# GUN POST LANES SNACK BAR
# Request failed with status code: 429
# KENNEDY FRIED CHICKEN & SALAD BAR
# Request failed with status code: 429
# BRISAS EXPRESS
# Request failed with status code: 429
# DAKAR AFRICAN RESTAURANT  & GRILL
# Request failed with status code: 429
# SIENTASE DE MARAVILLA
# Request failed with status code: 429
# KHALIL BIRYANI HOUSE/KHALIL HALAL CHINESE
# Request failed with status code: 429
# ESTRELLA BAR & RESTAURANT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-86a50c2125b1> in <cell line: 11>()
#      14         # Make the request to the Yelp API. The Radius is 100 meters because I believe based on the coordinates given by NYC, I will find at least the information from
#      15         url = f"https://api.yelp.com/v3/businesses/search?location=NYC&latitude={row['Latitude']}&longitude={row['Longitude']}&term=restaurants&radius=100&sort_by=review_count&limit=50&offset=1"
# ---> 16         response = requests.get(url, headers=headers)
#      17
#      18         # Check the status code
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     335             raise UnknownProtocol(version)
#     336
# --> 337         self.headers = self.msg = parse_headers(self.fp)
#     338
#     339         if self.debuglevel > 0:
#
# /usr/lib/python3.10/http/client.py in parse_headers(fp, _class)
#     233     """
#     234     headers = _read_headers(fp)
# --> 235     hstring = b''.join(headers).decode('iso-8859-1')
#     236     return email.parser.Parser(_class=_class).parsestr(hstring)
#     237
#
# KeyboardInterrupt:
